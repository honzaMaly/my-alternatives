# %%
from collections import Counter
import pandas as pd
import tensorflow as tf
import numpy as np
import tensorflow_recommenders as tfrs
from typing import Dict, Text

# %%
# setup HW
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# check HW availability
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print("Num CPUs Available: ", len(tf.config.experimental.list_physical_devices('CPU')))
# Out:
# Num GPUs Available:  1
# Num CPUs Available:  1

# %%
# load data
dataset_df = pd.read_csv('data/hackprague_txs.csv', sep = ";")
dataset_df.head()
# Out:
# /home/jan/miniconda3/envs/my-alternatives/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (8,12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    transaction_id     tx_date  client_id client_gender  client_year_of_birth  \
# 0               1  2020-07-02     146167        Female                1980.0
# 1               2  2020-06-11      40161        Female                1980.0
# 2               3  2020-08-14     200977        Female                1965.0
# 3               4  2020-06-10     200977        Female                1965.0
# 4               5  2020-05-27     200977        Female                1965.0
#
#    amount            merchant_uid      merchant_category           shop_tags  \
# 0    -594  X0noQaM22AHzkPN9erAb74  Professional Services  {Delivery Service}
# 1    -986  X0noQaM22AHzkPN9erAb74  Professional Services  {Delivery Service}
# 2    -102  g0DedJv2k5uqz5bYEjdQn8         Food And Drink                 NaN
# 3    -158  g0DedJv2k5uqz5bYEjdQn8         Food And Drink                 NaN
# 4    -126  g0DedJv2k5uqz5bYEjdQn8         Food And Drink                 NaN
#
#    merchant_category_id                shop_uid shop_type     region country
# 0             1483998.0  zYMe28Vm9LFEpAN18vaQvG  MERCHANT  Pardubice      CZ
# 1             1483998.0  zYMe28Vm9LFEpAN18vaQvG  MERCHANT  Pardubice      CZ
# 2                 147.0  MkBX1n9BjZFAGoly0Yq3Xy  MERCHANT     Kladno      CZ
# 3                 147.0  MkBX1n9BjZFAGoly0Yq3Xy  MERCHANT     Kladno      CZ
# 4                 147.0  MkBX1n9BjZFAGoly0Yq3Xy  MERCHANT     Kladno      CZ

# %%
# map categories

mapping = [
    {
        'category': 'Bakery',
        'type': 'Groceries',
        'tags': ['Bakery'],
        'places': ['bakery']
     },
    {
        'category': 'Alcohol',
        'type': 'Groceries',
        'tags': ['Alcohol'],
        'places': ['liquor store']
     },
    {
        'category': 'Restaurant',
        'type': 'Food And Drink',
        'tags': ['Restaurant', 'Cuisine', 'Fast Food', 'Bageterie', 'Steak House / Burgers', 'Sushi'],
        'places': ['restaurant']
     },
    {
        'category': 'Party',
        'type': 'Food And Drink',
        'tags': ['Bar', 'Music Club', 'Alcohol', 'Wine', 'Drinking', 'Bear', 'Pub'],
        'places': ['night_club', 'bar', 'pub']
     },
    {
        'category': 'Clothing',
        'type': 'Fashion',
        'tags': ['Fashion Chain - Mix', 'Fashion Accessories', 'Clothing - Other'],
        'places': ['clothing_store']
     },
    {
        'category': 'Pets',
        'type': 'Pets',
        'tags': ['Pet Supplies', 'Pets'],
        'places': ['pet store']
     }      
]

def map_category(x):
    cat: str = x[0]
    tags: str = x[1]

    if pd.isnull(tags):
        return None

    for item in mapping:
        if item['type'] == cat:
            if any(x in tags for x in item['tags']):
                return item['category']
    return None

dataset_filtered_df = dataset_df[dataset_df['merchant_category'].isin(list(map(lambda x: x['type'], mapping))) == True]
dataset_filtered_df['category'] = dataset_filtered_df[['merchant_category','shop_tags']].apply(map_category, axis=1)
dataset_filtered_df = dataset_filtered_df[~dataset_filtered_df['category'].isnull() & ~dataset_filtered_df['merchant_uid'].isnull()]
dataset_filtered_df.head()
# Out:
# <ipython-input-4-da1cc78c523e>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_filtered_df['category'] = dataset_filtered_df[['merchant_category','shop_tags']].apply(map_category, axis=1)
#       transaction_id     tx_date  client_id client_gender  \
# 2749            2750  2020-06-14     200428          Male
# 2750            2751  2020-09-19     169335          Male
# 2751            2752  2020-09-04     137596          Male
# 2752            2753  2020-08-28     111554        Female
# 2753            2754  2020-08-19      40631          Male
#
#       client_year_of_birth  amount            merchant_uid merchant_category  \
# 2749                1980.0    -105  beXJ9o0k3NSl9PaoEz4eR3    Food And Drink
# 2750                1995.0     -89  beXJ9o0k3NSl9PaoEz4eR3    Food And Drink
# 2751                1985.0    -950  beXJ9o0k3NSl9PaoEz4eR3    Food And Drink
# 2752                1990.0    -894  beXJ9o0k3NSl9PaoEz4eR3    Food And Drink
# 2753                1995.0    -644  beXJ9o0k3NSl9PaoEz4eR3    Food And Drink
#
#            shop_tags  merchant_category_id                shop_uid shop_type  \
# 2749  {Bar,Drinking}                 147.0  EWAavyAo2GT5LYqkPPoEnj  MERCHANT
# 2750  {Bar,Drinking}                 147.0  EWAavyAo2GT5LYqkPPoEnj  MERCHANT
# 2751  {Bar,Drinking}                 147.0  EWAavyAo2GT5LYqkPPoEnj  MERCHANT
# 2752  {Bar,Drinking}                 147.0  EWAavyAo2GT5LYqkPPoEnj  MERCHANT
# 2753  {Bar,Drinking}                 147.0  EWAavyAo2GT5LYqkPPoEnj  MERCHANT
#
#                   region country category
# 2749  Hlavní město Praha      CZ    Party
# 2750  Hlavní město Praha      CZ    Party
# 2751  Hlavní město Praha      CZ    Party
# 2752  Hlavní město Praha      CZ    Party
# 2753  Hlavní město Praha      CZ    Party

# %%
# filter users from Prague
users_in_prague = Counter(dataset_filtered_df[dataset_filtered_df['region'].str.contains("Praha") == True]['client_id'])
users_transactions = Counter(dataset_filtered_df[dataset_filtered_df['client_id'].isin(list(users_in_prague.keys()))]['client_id'])
users_to_keep = [k for k, v in users_in_prague.items() if (v / users_transactions[k]) > 0.8]

# update dataset
dataset_filtered_df = dataset_filtered_df.where(dataset_filtered_df['client_id'].isin(users_to_keep))

# %%
# prepare data
visits_df = dataset_filtered_df[~dataset_filtered_df['category'].isnull()
                             & ~dataset_filtered_df['merchant_uid'].isnull()][['client_id', 'merchant_uid']]\
    .drop_duplicates()

# %%
# create TF dataset - places + visits
visits = tf.data.Dataset.from_tensor_slices(np.array([[x[0], str(x[1])] for x in visits_df.values])).map(lambda x: {
    "merchant_uid": x[1],
    "client_id": x[0],
})
places = tf.data.Dataset.from_tensor_slices(visits_df['merchant_uid'].unique().reshape(-1, 1))

# %%
user_ids_vocabulary = tf.keras.layers.experimental.preprocessing.StringLookup(mask_token=None)
user_ids_vocabulary.adapt(visits.map(lambda x: x["client_id"]))

places_vocabulary = tf.keras.layers.experimental.preprocessing.StringLookup(mask_token=None)
places_vocabulary.adapt(places)

# %%
# train model

class MovieLensModel(tfrs.Model):
  # We derive from a custom base class to help reduce boilerplate. Under the hood,
  # these are still plain Keras Models.

  def __init__(
      self,
      user_model: tf.keras.Model,
      place_model: tf.keras.Model,
      task: tfrs.tasks.Retrieval):
    super().__init__()

    # Set up user and movie representations.
    self.user_model = user_model
    self.place_model = place_model

    # Set up a retrieval task.
    self.task = task

  def compute_loss(self, features: Dict[Text, tf.Tensor], training=False) -> tf.Tensor:
    # Define how the loss is computed.

    user_embeddings = self.user_model(features["client_id"])
    place_embeddings = self.place_model(features["merchant_uid"])

    return self.task(user_embeddings, place_embeddings)

# %%
# Define user and movie models.
user_model = tf.keras.Sequential([
    user_ids_vocabulary,
    tf.keras.layers.Embedding(user_ids_vocabulary.vocab_size(), 64)
])
place_model = tf.keras.Sequential([
    places_vocabulary,
    tf.keras.layers.Embedding(places_vocabulary.vocab_size(), 64)
])

# Define your objectives.
task = tfrs.tasks.Retrieval(metrics=tfrs.metrics.FactorizedTopK(
    places.batch(128).map(place_model)
  )
)

# %%
# Create a retrieval model.
model = MovieLensModel(user_model, place_model, task)
model.compile(optimizer=tf.keras.optimizers.Adagrad(0.5))

# Train for 3 epochs.
model.fit(visits.batch(2048), epochs=10)
# Out:
# Epoch 1/10
# WARNING:tensorflow:The dtype of the source tensor must be floating (e.g. tf.float32) when calling GradientTape.gradient, got tf.int32
# WARNING:tensorflow:Gradients do not exist for variables ['counter:0'] when minimizing the loss.
# WARNING:tensorflow:The dtype of the source tensor must be floating (e.g. tf.float32) when calling GradientTape.gradient, got tf.int32
# WARNING:tensorflow:Gradients do not exist for variables ['counter:0'] when minimizing the loss.
# 87/87 [==============================] - 7s 83ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0061 - factorized_top_k/top_5_categorical_accuracy: 0.0478 - factorized_top_k/top_10_categorical_accuracy: 0.0957 - factorized_top_k/top_50_categorical_accuracy: 0.3232 - factorized_top_k/top_100_categorical_accuracy: 0.4806 - loss: 15116.6121 - regularization_loss: 0.0000e+00 - total_loss: 15116.6121
# Epoch 2/10
# 87/87 [==============================] - 7s 83ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0320 - factorized_top_k/top_5_categorical_accuracy: 0.0912 - factorized_top_k/top_10_categorical_accuracy: 0.1354 - factorized_top_k/top_50_categorical_accuracy: 0.3490 - factorized_top_k/top_100_categorical_accuracy: 0.5227 - loss: 14588.5866 - regularization_loss: 0.0000e+00 - total_loss: 14588.5866
# Epoch 3/10
# 87/87 [==============================] - 7s 82ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0316 - factorized_top_k/top_5_categorical_accuracy: 0.1094 - factorized_top_k/top_10_categorical_accuracy: 0.1734 - factorized_top_k/top_50_categorical_accuracy: 0.4506 - factorized_top_k/top_100_categorical_accuracy: 0.6376 - loss: 12523.3828 - regularization_loss: 0.0000e+00 - total_loss: 12523.3828
# Epoch 4/10
# 87/87 [==============================] - 7s 79ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0332 - factorized_top_k/top_5_categorical_accuracy: 0.1347 - factorized_top_k/top_10_categorical_accuracy: 0.2144 - factorized_top_k/top_50_categorical_accuracy: 0.5221 - factorized_top_k/top_100_categorical_accuracy: 0.7108 - loss: 11696.5631 - regularization_loss: 0.0000e+00 - total_loss: 11696.5631
# Epoch 5/10
# 87/87 [==============================] - 8s 88ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0277 - factorized_top_k/top_5_categorical_accuracy: 0.1379 - factorized_top_k/top_10_categorical_accuracy: 0.2260 - factorized_top_k/top_50_categorical_accuracy: 0.5525 - factorized_top_k/top_100_categorical_accuracy: 0.7406 - loss: 11371.5910 - regularization_loss: 0.0000e+00 - total_loss: 11371.5910
# Epoch 6/10
# 87/87 [==============================] - 9s 100ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0258 - factorized_top_k/top_5_categorical_accuracy: 0.1403 - factorized_top_k/top_10_categorical_accuracy: 0.2322 - factorized_top_k/top_50_categorical_accuracy: 0.5738 - factorized_top_k/top_100_categorical_accuracy: 0.7637 - loss: 11218.2868 - regularization_loss: 0.0000e+00 - total_loss: 11218.2868
# Epoch 7/10
# 87/87 [==============================] - 10s 115ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0231 - factorized_top_k/top_5_categorical_accuracy: 0.1372 - factorized_top_k/top_10_categorical_accuracy: 0.2306 - factorized_top_k/top_50_categorical_accuracy: 0.5815 - factorized_top_k/top_100_categorical_accuracy: 0.7725 - loss: 11148.1219 - regularization_loss: 0.0000e+00 - total_loss: 11148.1219
# Epoch 8/10
# 87/87 [==============================] - 10s 112ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0233 - factorized_top_k/top_5_categorical_accuracy: 0.1370 - factorized_top_k/top_10_categorical_accuracy: 0.2329 - factorized_top_k/top_50_categorical_accuracy: 0.5906 - factorized_top_k/top_100_categorical_accuracy: 0.7840 - loss: 11095.9256 - regularization_loss: 0.0000e+00 - total_loss: 11095.9256
# Epoch 9/10
# 87/87 [==============================] - 10s 113ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0210 - factorized_top_k/top_5_categorical_accuracy: 0.1347 - factorized_top_k/top_10_categorical_accuracy: 0.2298 - factorized_top_k/top_50_categorical_accuracy: 0.5924 - factorized_top_k/top_100_categorical_accuracy: 0.7865 - loss: 11054.9313 - regularization_loss: 0.0000e+00 - total_loss: 11054.9313
# Epoch 10/10
# 87/87 [==============================] - 9s 107ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0216 - factorized_top_k/top_5_categorical_accuracy: 0.1342 - factorized_top_k/top_10_categorical_accuracy: 0.2317 - factorized_top_k/top_50_categorical_accuracy: 0.5990 - factorized_top_k/top_100_categorical_accuracy: 0.7947 - loss: 11019.5904 - regularization_loss: 0.0000e+00 - total_loss: 11019.5904

# %%
# Use brute-force search to set up retrieval using the trained representations.
index = tfrs.layers.factorized_top_k.BruteForce(model.user_model)
index.index(places.batch(100).map(model.place_model), places)

# Get some recommendations.
_, titles = index(tf.constant([str(users_to_keep[1])]))
print(users_to_keep[1])
print(f"Top N recommendations for user: {titles[0, :100]}")
# Out:
# 111554
# Top N recommendations for user: [b'qka7G41e3ZfEpPjENMNnZK' b'K70me03zXvH9N5rNyZondj'
#  b'2MmN44emyoIJr1WaGYlQA5' b'geknJ4ajBpc9aWGVLPRen2'
#  b'J9VENr0Q3ZSaZ7BoMqBZZK' b'09QVg32QZkcJEdk3bj7Zyv'
#  b'ozpJL2ea3pI9WbVVKDQ8NB' b'DLd2JkVvb1h4lo1WDzyNrM'
#  b'3ALPl5mQWoIQdJBb0agdry' b'LedJkgpompCydrPEVoPvk2']
